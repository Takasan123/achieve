# %% [markdown]
# ## AIF_sprint28_SQL
# ### この課題の目的
# データベースのテーブルを操作できるようになる
# 【目的としないこと】
# SQLのコマンドの種類を覚える

# %%
import matplotlib.pyplot as plt
import cv2
img = cv2.imread("/Users/andoutakaaki/DIC_study/sprint28/erdplus-diagram.png")
img_expand = img.repeat(2,axis=0).repeat(2,axis=1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ## Question
#
# - user_id 1のuserが注文した件数:796件
# --コード--
# SELECT COUNT(USER_id)
# FROM
#   orders
# WHERE
#   USER_id = 1
#
# ;
#
# - 最後に注文したuserの名前: 49 Alexandria Buckridge
# --コード--
# SELECT USER_id
# FROM
#   orders
# ORDER BY
#   created_at DESC
# ,  USER_id
#
# ;
# - cityの名称一覧(id, nameのみ出力)
# --コード--
# SELECT
#   id
# , name
# FROM
#   cities
# GROUP BY
#    id
# ,  name
#
# ORDER BY
#    id ASC
#
#
# ;
#
#
#
# "id","name"
# 1,"市区町村"
# 2,"千代田区"
# 3,"中央区"
# 4,"港区"
# 5,"新宿区"
# 6,"文京区"
# 7,"台東区"
# 8,"墨田区"
# 9,"江東区"
# 10,"品川区"
# 11,"目黒区"
# 12,"大田区"
# 13,"世田谷区"
# 14,"渋谷区"
# 15,"中野区"
# 16,"杉並区"
# 17,"豊島区"
# 18,"北区"
# 19,"荒川区"
# 20,"板橋区"
# 21,"練馬区"
# 22,"足立区"
# 23,"葛飾区"
# 24,"江戸川区"
# 25,"八王子市"
# 26,"立川市"
# 27,"武蔵野市"
# 28,"三鷹市"
# 29,"青梅市"
# 30,"府中市"
# 31,"昭島市"
# 32,"調布市"
# 33,"町田市"
# 34,"小金井市"
# 35,"小平市"
# 36,"日野市"
# 37,"東村山市"
# 38,"国分寺市"
# 39,"国立市"
# 40,"福生市"
# 41,"狛江市"
# 42,"東大和市"
# 43,"清瀬市"
# 44,"東久留米市"
# 45,"武蔵村山市"
# 46,"多摩市"
# 47,"稲城市"
# 48,"羽村市"
# 49,"あきる野市"
# 50,"西東京市"
# 51,"西多摩郡瑞穂町"
# 52,"西多摩郡日の出町"
# 53,"西多摩郡檜原村"
# 54,"西多摩郡奥多摩町"
# 55,"大島町"
# 56,"利島村"
# 57,"新島村"
# 58,"神津島村"
# 59,"三宅島三宅村"
# 60,"御蔵島村"
# 61,"八丈島八丈町"
# 62,"青ヶ島村"
# 63,"小笠原村"
#
# - 渋谷区のshop一覧取得:785件取得
# 一部記載
# "id","name"
# 22,"Red Wine Vinegar shop"
# 79,"Spinach shop"
# 143,"Dates shop"
# 233,"Common Cultivated Mushrooms shop"
# 244,"Snapper shop"
# 247,"Vinegar shop"
# 275,"Flat Mushrooms shop"
# 285,"Pistachio Nut shop"
# 374,"Kangaroo shop"
# 379,"Arugula shop"
# 406,"Adzuki Beans shop"
# 412,"Nectarines shop"
# 459,"Muesli shop"
# 499,"Coconut shop"
# 507,"Duck shop"
# 777,"Allspice shop"
# 932,"Maple Syrup shop"
# 990,"Oysters shop"
# 1096,"Pomegranate shop"
# 1098,"Mackerel shop"
# 1112,"Cranberry shop"
# 1227,"Vermicelli Noodles shop"
# 1228,"Endive shop"
# 1255,"Peppers shop"
# 1307,"Dark Chocolate shop"
# 1556,"Coconut shop"
# 1646,"Mahlab shop"
#
# --コード--
# SELECT
#   id
# , name
# FROM
#   shops
#
# WHERE
#   city_id = 14
#
# ORDER BY
#    id ASC
#
#
# ;
#
#
# - 1のuserが注文した料理一覧を取得:３種類の料理を796件注文
# Pork sausage roll
# Pasta with Tomato and Basil
# Lasagne
#
# --コード--
# SELECT
#   foods.name
# , order_foods.id
#
# FROM
#   orders
# JOIN
#   order_foods
# ON
#   orders.id = order_foods.order_id
#
# JOIN
#   foods
# ON
#   order_foods.food_id = foods.id
#
# WHERE
#   orders.user_id = 1
#
#
# ;
#
#
#
# - 1のuserが注文した料理の合計金額を取得:1,081,000円
#
# SELECT SUM(foods.price)
#
# FROM
#   orders
# JOIN
#   order_foods
# ON
#   orders.id = order_foods.order_id
#
# JOIN
#   foods
# ON
#   order_foods.food_id = foods.id
#
# WHERE
#   orders.user_id = 1
#
#
# ;
#
#
# - 全てのuserの注文金額をそれぞれ取得
#
# "user_id","name","sum"
# 1,"Gretchen Quigley",1081000
# 2,"Celestino Roob",1049000
# 3,"Dameon Runolfsdottir",1006500
# 4,"Mrs. Bennett Hirthe",1049500
# 5,"Gennaro Little DDS",991500
# 6,"Daija Sawayn",1101500
# 7,"Icie Runolfsson",1085000
# 8,"Marilou Ryan",1053000
# 9,"Rosemarie Wyman",1044500
# 10,"Beryl VonRueden III",1057500
# 11,"Xander Feeney",1027000
# 12,"Francesco Luettgen",1094500
# 13,"Davon Bernhard",999500
# 14,"Bert Dare",1101500
# 15,"Miracle Stiedemann",1110000
# 16,"Earl Rohan",1073500
# 17,"Pierce Carter",1051000
# 18,"Zack Hettinger",1017500
# 19,"Lea Ondricka PhD",1020000
# 20,"Mrs. Ardith Hoppe",1068000
# 21,"Dr. Alfred Langworth",1085000
# 22,"Skylar Cronin",1084500
# 23,"Emmie Blick",1013000
# 24,"Mr. Napoleon Gulgowski",1062000
# 25,"Gaylord Treutel",1088500
# 26,"Ms. Jo Lemke",1118000
# 27,"Oren Blanda II",1090000
# 28,"Dr. Kayley Sanford",1001500
# 29,"Ms. Jude Conroy",1045500
# 30,"Janet Hand MD",931000
# 31,"Lavern Abernathy MD",1062000
# 32,"Gregory Rolfson III",1134000
# 33,"Madelynn Gleichner",1099000
# 34,"Merle Bahringer",1106500
# 35,"Saul Hartmann",1043500
# 36,"Monty Gutkowski",1055500
# 37,"Dina Wintheiser",1048000
# 38,"Miss Haylee Schaefer",1054500
# 39,"Beau Simonis",1121000
# 40,"Gia Ferry",1038000
# 41,"Mr. Lucius Blanda",1031500
# 42,"Lane Hermann III",1066000
# 43,"Lemuel Friesen",1126000
# 44,"Jaclyn Fahey",1063000
# 45,"Skyla Erdman",1024500
# 46,"Russ Emmerich",989500
# 47,"Ola Hermiston",1048500
# 48,"Randy Bergnaum",1061000
# 49,"Alexandria Buckridge",1010500
# 50,"Diamond Ondricka",1068500
# 51,"Gudrun Johns",1077000
# 52,"Leonora Weber",1051000
# 53,"Miss Maureen Legros",1015000
# 54,"Mr. Kayley Stehr",1096500
# 55,"Jamey Casper",1117500
# 56,"Alec White Jr.",1078500
# 57,"Einar Crist",1017500
# 58,"Mrs. Pearlie Gulgowski",1007000
# 59,"Dr. Tia Thompson",1049500
# 60,"Kristy Mann",1116000
# 61,"Lillian Gerlach II",1087000
# 62,"Pinkie Wolff",1069500
# 63,"Rosalee Collins V",984000
#
# --コード--
# SELECT
#   orders.user_id
# , users.name
# , SUM(foods.price)
# FROM
#   orders
# JOIN
#   order_foods
# ON
#   orders.id = order_foods.order_id
# JOIN
#   foods
# ON
#   order_foods.food_id = foods.id
# JOIN
#   users
# ON
#   users.id = ORders.user_id
# GROUP BY
#    orders.user_id
# ,  users.name
# ORDER BY
#    orders.user_id ASC
#
# ;
#
# - 全てのuserの注文金額が高い順に並び替えて名前と金額を取得:189行
# 一部掲載
# 1,"Gretchen Quigley","Pork sausage roll",560000
# 1,"Gretchen Quigley","Pasta with Tomato and Basil",394500
# 1,"Gretchen Quigley","Lasagne",126500
# 2,"Celestino Roob","Pork sausage roll",520000
# 2,"Celestino Roob","Pasta with Tomato and Basil",385500
# 2,"Celestino Roob","Lasagne",143500
# 3,"Dameon Runolfsdottir","Pork sausage roll",500000
# 3,"Dameon Runolfsdottir","Pasta with Tomato and Basil",370500
# 3,"Dameon Runolfsdottir","Lasagne",136000
# 4,"Mrs. Bennett Hirthe","Pork sausage roll",488000
# 4,"Mrs. Bennett Hirthe","Pasta with Tomato and Basil",409500
# 4,"Mrs. Bennett Hirthe","Lasagne",152000
# 5,"Gennaro Little DDS","Pork sausage roll",502000
# 5,"Gennaro Little DDS","Pasta with Tomato and Basil",363000
# 5,"Gennaro Little DDS","Lasagne",126500
# 6,"Daija Sawayn","Pork sausage roll",544000
# 6,"Daija Sawayn","Pasta with Tomato and Basil",438000
# 6,"Daija Sawayn","Lasagne",119500
#
# --コード--
# SELECT
#   orders.user_id
# , users.name
# , foods.name
# , SUM(foods.price)
# FROM
#   orders
# JOIN
#   order_foods
# ON
#   orders.id = order_foods.order_id
# JOIN
#   foods
# ON
#   order_foods.food_id = foods.id
# JOIN
#   users
# ON
#   users.id = ORders.user_id
# GROUP BY
#    orders.user_id
# ,  users.name
# , foods.name
# , foods.price
#
# ORDER BY
#   orders.user_id  ASC
# , SUM(foods.price) DESC
#
# ;
#
# - category別の商品一覧を取得:111行、一部掲載
# 1,"魚","Barbecue Ribs"
# 1,"魚","Bruschette with Tomato"
# 1,"魚","Caesar Salad"
# 1,"魚","Califlower penne"
# 1,"魚","California maki"
# 1,"魚","Caprese Salad"
# 1,"魚","Cheeseburger"
# 1,"魚","Chicken Fajitas"
# 1,"魚","Chicken milanese"
# 1,"魚","Chicken wings"
# 1,"魚","Chilli con carne"
# 1,"魚","Ebiten maki"
# 1,"魚","Fettuccine Alfredo"
# 1,"魚","Fish and chips"
# 1,"魚","French fries with sausages"
# 1,"魚","Katsu Curry"
# 1,"魚","Lasagne"
# 1,"魚","Linguine with clams"
# 1,"魚","Meatballs with sauce"
# 1,"魚","Mushroom Risotto"
# 1,"魚","Pappardelle alla Bolognese"
# 1,"魚","Pasta Carbonara"
# 1,"魚","Pasta and Beans"
# 1,"魚","Pasta with Tomato and Basil"
#
# --コード--
# SELECT
#    categories.id
# ,  categories.name
# ,  foods.name
# FROM
#   categories
# JOIN
#   foods
# ON
#   categories.id =foods.category_id
# GROUP BY
#   categories.id
# , categories.name
# , foods.name
#
# ORDER BY
#   categories.id  ASC
# , foods.name ASC
#
# ;
#
# - userの名前に"a"が含まれる人を出力
# "name"
# "Alexandria Buckridge"
# "Beau Simonis"
# "Bert Dare"
# "Daija Sawayn"
# "Dameon Runolfsdottir"
# "Davon Bernhard"
# "Diamond Ondricka"
# "Dina Wintheiser"
# "Dr. Alfred Langworth"
# "Dr. Kayley Sanford"
# "Dr. Tia Thompson"
# "Earl Rohan"
# "Einar Crist"
# "Francesco Luettgen"
# "Gaylord Treutel"
# "Gennaro Little DDS"
# "Gia Ferry"
# "Jaclyn Fahey"
# "Jamey Casper"
# "Janet Hand MD"
# "Kristy Mann"
# "Lane Hermann III"
# "Lavern Abernathy MD"
# "Lea Ondricka PhD"
# "Leonora Weber"
# "Lillian Gerlach II"
# "Madelynn Gleichner"
# "Marilou Ryan"
# "Merle Bahringer"
# "Miracle Stiedemann"
# "Miss Haylee Schaefer"
# "Miss Maureen Legros"
# "Mr. Kayley Stehr"
# "Mr. Lucius Blanda"
# "Mr. Napoleon Gulgowski"
# "Mrs. Pearlie Gulgowski"
# "Ola Hermiston"
# "Oren Blanda II"
# "Pierce Carter"
# "Randy Bergnaum"
# "Rosalee Collins V"
# "Rosemarie Wyman"
# "Saul Hartmann"
# "Skyla Erdman"
# "Skylar Cronin"
# "Xander Feeney"
# "Zack Hettinger"
#
# --コード--
# SELECT
#   users.name
# FROM
#   users
# WHERE
#   users.name LIKE '%a%'
# ORDER BY
#   users.name ASC
#
# ;
# - userのidが5以下の人たち
# "id","name"
# 1,"Gretchen Quigley"
# 2,"Celestino Roob"
# 3,"Dameon Runolfsdottir"
# 4,"Mrs. Bennett Hirthe"
# 5,"Gennaro Little DDS"
#
# --コード--
# SELECT
#   users.id
# , users.name
# FROM
#   users
# GROUP BY
#   users.id
# HAVING
#   users.id <= 5
# ORDER BY
#   users.id ASC
#
# ;
#
# - 注文をしたuserの中で注文数が多い順に5人限定で並べる
# "Miracle Stiedemann",847
# "Lemuel Friesen",840
# "Beau Simonis",836
# "Gregory Rolfson III",834
# "Ms. Jo Lemke",833
#
# --コード--
# SELECT
#   users.name
# , COUNT(users.id)
#
# FROM
#   orders
# JOIN
#   users
# ON
#   orders.user_id = users.id
# GROUP BY
#   users.id
# , users.name
# ORDER BY
#   COUNT(users.id) DESC LIMIT 5
#
# ;
